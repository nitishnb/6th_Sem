# %%
from pgmpy.models import BayesianModel
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

# %%
# !pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\asus\anaconda3\lib\site-packages (0.1.14)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (0.25.1)
# Requirement already satisfied: scikit-learn in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (0.21.3)
# Requirement already satisfied: scipy in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (1.3.1)
# Requirement already satisfied: statsmodels in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (0.10.1)
# Requirement already satisfied: networkx in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (2.3)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (1.16.5)
# Requirement already satisfied: tqdm in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (4.36.1)
# Requirement already satisfied: pyparsing in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (2.4.2)
# Requirement already satisfied: torch in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (1.8.1)
# Requirement already satisfied: joblib in c:\users\asus\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas->pgmpy) (2019.3)
# Requirement already satisfied: patsy>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\asus\anaconda3\lib\site-packages (from networkx->pgmpy) (4.4.0)
# Requirement already satisfied: typing-extensions in c:\users\asus\anaconda3\lib\site-packages (from torch->pgmpy) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgmpy) (1.12.0)

# %%
model=BayesianModel([('Rain','Sprinkler'),('Rain','Grass_wet'),('Sprinkler','Grass_wet')])
print('Bayesian network models are :')
print('\t',model.nodes())
print('Bayesian edges are:')
print('\t',model.edges())
# Out:
# Bayesian network models are :
# 	 ['Rain', 'Sprinkler', 'Grass_wet']
# Bayesian edges are:
# 	 [('Rain', 'Sprinkler'), ('Rain', 'Grass_wet'), ('Sprinkler', 'Grass_wet')]

# %%
rain = TabularCPD(variable='Rain',variable_card=2,values=[[0.2],[0.8]])
sprinkler = TabularCPD(variable='Sprinkler',variable_card=2,values=[[0.01,0.4],[0.99,0.6]],
                     evidence=['Rain'],evidence_card=[2])
grass_wet = TabularCPD(variable='Grass_wet',variable_card=2,values=[[0.99,0.9,0.8,0.0],
                                                                 [0.01,0.1,0.2,1.0]],
                       evidence=['Sprinkler','Rain'],
                       evidence_card=[2,2])

# %%
model.add_cpds(rain,sprinkler,grass_wet)
print('Model generated by adding cpts(cpds)')
print('Checking correctness of model:',end='')
print(model.check_model())
# Out:
# Model generated by adding cpts(cpds)
# Checking correctness of model:True

# %%
infer=VariableElimination(model)

# %%
print('All local independecies are as follows')
model.get_independencies()
print('Displaying  CPDs')
print(model.get_cpds('Rain'))
print(model.get_cpds('Sprinkler'))
print(model.get_cpds('Grass_wet'))
# Out:
# All local independecies are as follows
# Displaying  CPDs
# +---------+-----+
# | Rain(0) | 0.2 |
# +---------+-----+
# | Rain(1) | 0.8 |
# +---------+-----+
# +--------------+---------+---------+
# | Rain         | Rain(0) | Rain(1) |
# +--------------+---------+---------+
# | Sprinkler(0) | 0.01    | 0.4     |
# +--------------+---------+---------+
# | Sprinkler(1) | 0.99    | 0.6     |
# +--------------+---------+---------+
# +--------------+--------------+--------------+--------------+--------------+
# | Sprinkler    | Sprinkler(0) | Sprinkler(0) | Sprinkler(1) | Sprinkler(1) |
# +--------------+--------------+--------------+--------------+--------------+
# | Rain         | Rain(0)      | Rain(1)      | Rain(0)      | Rain(1)      |
# +--------------+--------------+--------------+--------------+--------------+
# | Grass_wet(0) | 0.99         | 0.9          | 0.8          | 0.0          |
# +--------------+--------------+--------------+--------------+--------------+
# | Grass_wet(1) | 0.01         | 0.1          | 0.2          | 1.0          |
# +--------------+--------------+--------------+--------------+--------------+

# %%
print('\n The probability that it is raining, given the grass is wet is: ')
q=infer.query(variables=['Rain'],evidence={'Grass_wet':1})
print(q)
# Out:
#  The probability that it is raining, given the grass is wet is:
# Finding Elimination Order: : 100%|██████████| 1/1 [00:00<00:00, 254.09it/s]
# Eliminating: Sprinkler: 100%|██████████| 1/1 [00:00<00:00, 264.29it/s]
# +---------+-------------+
# | Rain    |   phi(Rain) |
# +=========+=============+
# | Rain(0) |      0.0718 |
# +---------+-------------+
# | Rain(1) |      0.9282 |
# +---------+-------------+
